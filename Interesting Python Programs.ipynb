# %% [markdown]
# ### Random Password Generator

# %%
import string
from random import *

# %%
characters=string.ascii_letters+string.punctuation+string.digits
print(characters)
print()
passwd="".join(choice(characters) for x in range(randint(6,6)))
print("Random Password Generated =",passwd)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~0123456789
#
# Random Password Generated = qB[#[j

# %% [markdown]
# ### Generate QR Code

# %%
pip install qrcode
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode

# %% [markdown]
# Procedure to create our own QR Codes
# - Install qrcode module using pip
# - import qrcode
# - qrcode.make(url)
# - save image with any extension at any place

# %%
url=input("Enter URL to generate QR Code:")
image=qrcode.make(url)
image.save("C:/Users/Administrator/Desktop/SimplyCS.in_QR_Code1.jpeg")
# Out:
# Enter URL to generate QR Code:www.simplycs.in
# ...

# %%
image

# %% [markdown]
# ### Access Camera Using Python and opencv

# %%
import cv2

# %%
#Open Camera
cap=cv2.VideoCapture(0)
if not (cap.isOpened()):
    print("Could not open video device")

#To set the resolution
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# Grab the frame Continuosly
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    # Display the resulting frame
    cv2.imshow('preview',frame)
    #Waits for a user input to quit the application
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    #Waits for a user input to quit the application
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Read Image using PIL library and see image data

# %%
from PIL import Image

# %%
img=Image.open("C:/Users/Administrator/Desktop/rait.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=602x382 at 0x5044E90>

# %%
import numpy as np

# %%
img_data=np.array(img)
print(img_data)
# Out:
# [[[ 12  18   8]
#   [ 11  17   7]
#   [  7  13   3]
#   ...
#   [ 14  29  24]
#   [ 56  73  67]
#   [ 67  84  76]]
#
#  [[  9  15   5]
#   [ 11  17   7]
#   [  8  14   4]
#   ...
#   [ 18  30  26]
#   [ 26  41  34]
#   [ 30  45  38]]
#
#  [[  4  10   0]
#   [  8  14   4]
#   [  7  13   3]
#   ...
#   [ 20  29  24]
#   [ 19  30  24]
#   [ 15  26  20]]
#
#  ...
#
#  [[134  90  53]
#   [136  92  55]
#   [139  95  60]
#   ...
#   [ 59  32  25]
#   [ 18  13  19]
#   [ 13  19  31]]
#
#  [[153 107  71]
#   [151 105  69]
#   [146 100  64]
#   ...
#   [121  91  83]
#   [ 18  11  18]
#   [ 14  17  32]]
#
#  [[143  97  61]
#   [140  94  58]
#   [134  88  52]
#   ...
#   [168 135 126]
#   [ 23  13  22]
#   [ 16  19  36]]]

# %%
img.filename
# Out:
# 'C:/Users/Administrator/Desktop/rait.jpg'

# %%
img.format
# Out:
# 'JPEG'

# %%
img.show()

# %%
img.width
# Out:
# 602

# %%
img.height
# Out:
# 382

# %%
img.size
# Out:
# (602, 382)

# %%
img1=img.rotate(30)

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=602x382 at 0xCAA0290>
